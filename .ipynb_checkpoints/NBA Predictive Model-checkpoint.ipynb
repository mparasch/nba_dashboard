# %%
import nba_data as nba
import pandas as pd
import numpy as np

# %%
df = nba.run_all()

# %%
df.head()
# Out:
#       Season       Date Game_Day Time_ET               Vis_Team  Vis_Pts  \
# 0  2017-2018 2017-12-01      Fri   7:00p  Golden State Warriors      133
# 1  2017-2018 2017-12-01      Fri   7:00p        Detroit Pistons       91
# 2  2017-2018 2017-12-01      Fri   7:30p         Indiana Pacers      115
# 3  2017-2018 2017-12-01      Fri   8:00p       Sacramento Kings      107
# 4  2017-2018 2017-12-01      Fri   8:00p      San Antonio Spurs       95
#
#             Home_Team  Home_Pts   OT  Attend  ... 2019-2020_TeamWinPct  \
# 0       Orlando Magic       112  NaN   18846  ...             0.489362
# 1  Washington Wizards       109  NaN   17885  ...             0.382979
# 2     Toronto Raptors       120  NaN   19800  ...             0.695652
# 3       Chicago Bulls       106  NaN   19268  ...             0.355556
# 4   Memphis Grizzlies        79  NaN   16413  ...             0.574468
#
#   2017-2018_OppPtsFor  2017-2018_OppPtsAllowed  2017-2018_OppWinPct  \
# 0          112.462963               106.888889             0.722222
# 1          102.321429               104.125000             0.392857
# 2          104.500000               102.351852             0.611111
# 3          101.107143               107.285714             0.321429
# 4          102.781818                99.836364             0.545455
#
#    2018-2019_OppPtsFor  2018-2019_OppPtsAllowed  2018-2019_OppWinPct  \
# 0           118.245283               111.509434             0.698113
# 1           106.157895               106.824561             0.473684
# 2           108.690909               105.163636             0.581818
# 3           113.910714               113.678571             0.500000
# 4           113.127273               109.690909             0.618182
#
#    2019-2020_OppPtsFor  2019-2020_OppPtsAllowed  2019-2020_OppWinPct
# 0           105.911111               114.444444             0.244444
# 1           107.382979               111.446809             0.297872
# 2           109.217391               108.543478             0.586957
# 3           110.847826               112.217391             0.434783
# 4           113.930233               115.209302             0.465116
#
# [5 rows x 36 columns]

# %%
df = nba.keep_features(df)

# %%
df.head()
# Out:
#      Loc  Outcome  R_TeamPtsFor  R_TeamPtsFor  R_TeamWinPct  R_TeamWinPct  \
# 148    1        1         111.2         111.2           0.8           0.8
# 151    1        1         104.0         104.0           0.3           0.3
# 152    1        1         101.0         101.0           0.3           0.3
# 153    1        1          97.5          97.5           0.3           0.3
# 154    1        0         100.7         100.7           0.2           0.2
#
#      R_OppPtsFor  R_OppPtsFor  R_OppWinPct  R_OppWinPct  ...  \
# 148        103.4        103.4          0.3          0.3  ...
# 151        101.8        101.8          0.8          0.8  ...
# 152         98.8         98.8          0.3          0.3  ...
# 153        103.0        103.0          0.4          0.4  ...
# 154        118.0        118.0          0.6          0.6  ...
#
#      2019-2020_TeamWinPct  2017-2018_OppPtsFor  2017-2018_OppPtsAllowed  \
# 148              0.304348           105.500000               110.750000
# 151              0.382979            98.928571               106.000000
# 152              0.644444           102.781818                99.836364
# 153              0.297872           104.553571               109.785714
# 154              0.489362           112.436364               111.672727
#
#      2017-2018_OppWinPct  2018-2019_OppPtsFor  2018-2019_OppPtsAllowed  \
# 148             0.392857           105.888889               113.722222
# 151             0.250000           102.232143               106.500000
# 152             0.545455           113.127273               109.690909
# 153             0.285714           103.547170               114.415094
# 154             0.581818           114.309091               116.490909
#
#      2018-2019_OppWinPct  2019-2020_OppPtsFor  2019-2020_OppPtsAllowed  \
# 148             0.296296           107.200000               109.755556
# 151             0.321429           114.042553               112.212766
# 152             0.618182           113.930233               115.209302
# 153             0.132075           107.574468               113.510638
# 154             0.381818           116.666667               115.977778
#
#      2019-2020_OppWinPct
# 148             0.355556
# 151             0.574468
# 152             0.465116
# 153             0.361702
# 154             0.488889
#
# [5 rows x 28 columns]

# %%
df.describe()
# Out:
#           Loc      Outcome  R_TeamPtsFor  R_TeamPtsFor  R_TeamWinPct  \
# count  2179.0  2179.000000   2179.000000   2179.000000   2179.000000
# mean      1.0     0.569527    109.758330    109.758330      0.495824
# std       0.0     0.495256      6.016469      6.016469      0.209543
# min       1.0     0.000000     92.500000     92.500000      0.000000
# 25%       1.0     0.000000    105.500000    105.500000      0.300000
# 50%       1.0     1.000000    110.000000    110.000000      0.500000
# 75%       1.0     1.000000    114.200000    114.200000      0.600000
# max       1.0     1.000000    129.100000    129.100000      1.000000
#
#        R_TeamWinPct  R_OppPtsFor  R_OppPtsFor  R_OppWinPct  R_OppWinPct  ...  \
# count   2179.000000  2179.000000  2179.000000  2179.000000  2179.000000  ...
# mean       0.495824   109.889491   109.889491     0.496237     0.496237  ...
# std        0.209543     5.686092     5.686092     0.211394     0.211394  ...
# min        0.000000    90.300000    90.300000     0.000000     0.000000  ...
# 25%        0.300000   106.200000   106.200000     0.300000     0.300000  ...
# 50%        0.500000   109.900000   109.900000     0.500000     0.500000  ...
# 75%        0.600000   113.550000   113.550000     0.600000     0.600000  ...
# max        1.000000   126.800000   126.800000     1.000000     1.000000  ...
#
#        2019-2020_TeamWinPct  2017-2018_OppPtsFor  2017-2018_OppPtsAllowed  \
# count           2179.000000          2179.000000              2179.000000
# mean               0.499582           106.687110               106.722912
# std                0.155033             3.857107                 3.256823
# min                0.195652            98.928571                99.836364
# 25%                0.361702           103.759259               104.581818
# 50%                0.488889           106.636364               107.285714
# 75%                0.625000           110.444444               109.436364
# max                0.800000           113.309091               112.574074
#
#        2017-2018_OppWinPct  2018-2019_OppPtsFor  2018-2019_OppPtsAllowed  \
# count          2179.000000          2179.000000              2179.000000
# mean              0.498249           111.219642               111.266127
# std               0.158663             4.300865                 3.953171
# min               0.203704           102.232143               103.890909
# 25%               0.333333           107.660714               108.203704
# 50%               0.545455           112.870370               111.865385
# 75%               0.611111           114.309091               114.381818
# max               0.818182           118.245283               119.148148
#
#        2018-2019_OppWinPct  2019-2020_OppPtsFor  2019-2020_OppPtsAllowed  \
# count          2179.000000          2179.000000              2179.000000
# mean              0.498541           111.907304               111.844532
# std               0.153381             3.750858                 3.671327
# min               0.132075           101.636364               106.422222
# 25%               0.400000           109.217391               108.777778
# 50%               0.500000           112.911111               110.681818
# 75%               0.634615           114.042553               114.444444
# max               0.750000           117.933333               120.000000
#
#        2019-2020_OppWinPct
# count          2179.000000
# mean              0.501608
# std               0.156336
# min               0.195652
# 25%               0.361702
# 50%               0.489362
# 75%               0.625000
# max               0.800000
#
# [8 rows x 28 columns]

# %%
X = df[[col for col in df.columns if col!='Outcome']]
y = df['Outcome']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7)

# %%
clf = DecisionTreeClassifier(max_depth=2)
clf.fit(X_train, y_train)
accuracy_score(y_test, clf.predict(X_test))
# Out:
# 0.6199213630406291

# %%
plot_tree(clf)
# Out:
# [Text(167.4, 181.2, 'X[22] <= 0.518\ngini = 0.488\nsamples = 653\nvalue = [275, 378]'),
#  Text(83.7, 108.72, 'X[34] <= 0.591\ngini = 0.486\nsamples = 313\nvalue = [183, 130]'),
#  Text(41.85, 36.23999999999998, 'gini = 0.5\nsamples = 208\nvalue = [103, 105]'),
#  Text(125.55000000000001, 36.23999999999998, 'gini = 0.363\nsamples = 105\nvalue = [80, 25]'),
#  Text(251.10000000000002, 108.72, 'X[28] <= 0.46\ngini = 0.395\nsamples = 340\nvalue = [92, 248]'),
#  Text(209.25, 36.23999999999998, 'gini = 0.195\nsamples = 128\nvalue = [14, 114]'),
#  Text(292.95, 36.23999999999998, 'gini = 0.465\nsamples = 212\nvalue = [78, 134]')]

# %%
clf = RandomForestClassifier(n_estimators=50, max_depth=2)
clf.fit(X_train, y_train)
accuracy_score(y_test, clf.predict(X_test))
# Out:
# 0.6225425950196593

# %%
proba = clf.predict_proba(X_test)

# %%
predict = clf.predict(X_test)

# %%
proba
# Out:
# array([[0.47632772, 0.52367228],
#        [0.55274325, 0.44725675],
#        [0.52430042, 0.47569958],
#        ...,
#        [0.54908356, 0.45091644],
#        [0.40765529, 0.59234471],
#        [0.47163061, 0.52836939]])

# %%
arr2 = np.hsplit(proba, 2)

# %%
arr2[0].flatten()
# Out:
# array([0.47632772, 0.55274325, 0.52430042, ..., 0.54908356, 0.40765529,
#        0.47163061])

# %%
predict
# Out:
# (1526,)

# %%
arr = np.stack((y_test, predict, arr2[0].flatten(), arr2[1].flatten()), axis=1)

# %%
arr
# Out:
# array([[0.        , 1.        , 0.47632772, 0.52367228],
#        [1.        , 0.        , 0.55274325, 0.44725675],
#        [1.        , 0.        , 0.52430042, 0.47569958],
#        ...,
#        [0.        , 0.        , 0.54908356, 0.45091644],
#        [0.        , 1.        , 0.40765529, 0.59234471],
#        [1.        , 1.        , 0.47163061, 0.52836939]])

# %%
df_result = pd.DataFrame(arr, columns=['actual', 'predict', '0', '1'])

# %%
df_result.head()
# Out:
#    actual  predict         0         1
# 0     0.0      1.0  0.476328  0.523672
# 1     1.0      0.0  0.552743  0.447257
# 2     1.0      0.0  0.524300  0.475700
# 3     1.0      1.0  0.240923  0.759077
# 4     0.0      1.0  0.325455  0.674545

# %%
df_result.sort_values(by='1', ascending=False, inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
